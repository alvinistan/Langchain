# %% [markdown]
# ### Langchain Version V1

# %%
1+1
# Out:
# 2

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain.agents import create_agent

agent=create_agent(
    model="gpt-5",
    tools =[],
    system_prompt="You are a helpful assistant"
)
agent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from langchain.agents import create_agent
#       2
#       3 agent=create_agent(
#       4     model="gpt-5",
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (e:\Projects\Langchain\.venv\Lib\site-packages\langchain\agents\__init__.py)
